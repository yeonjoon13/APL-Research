# %%
import intern
from intern import array

# %%
boss_data = intern.array("bossdb://takemura/takemura13/image")

# %%
boss_data.shape
# Out:
# (1460, 12000, 12000)

# %%
downloaded_data = boss_data[700:710, 10000:11000, 10000:11000]

# %%
downloaded_data
# Out:
# VolumeCutout([[[ 86,  80,  80, ..., 164, 168, 186],
#                [ 90,  87,  82, ..., 152, 167, 188],
#                [100,  88,  84, ..., 148, 163, 181],
#                ...,
#                [135, 128, 122, ..., 127, 128, 137],
#                [111, 119, 119, ..., 132, 139, 146],
#                [116, 134, 127, ..., 137, 146, 151]],
#
#               [[100,  96,  99, ...,  68,  76,  71],
#                [ 96,  95,  87, ...,  58,  63,  60],
#                [ 90,  92,  94, ...,  55,  57,  61],
#                ...,
#                [120, 105,  95, ..., 169, 157, 163],
#                [124, 101,  92, ..., 161, 156, 152],
#                [127, 101,  95, ..., 145, 146, 138]],
#
#               [[104, 112, 108, ..., 117, 103,  94],
#                [115, 121, 118, ..., 127, 114,  98],
#                [116, 120, 119, ..., 134, 126, 105],
#                ...,
#                [140, 140, 151, ...,  91,  89,  90],
#                [148, 149, 158, ..., 102, 104, 107],
# ...

# %%
plt.imshow(downloaded_data[0])
